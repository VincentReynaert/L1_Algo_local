# %%
from webbot import Browser
from selenium.webdriver.chrome.options import Options

# %%
location = "C:\\Program Files\\Google\\Chrome\\Application"

options = Options()
options.binary_location = location

# %%
web = Browser()

# %%
web.go_to("https://agora.univ-catholille.fr/isacademia/PORTAL3S.htm")

# %%
web.type("2016546053",into="username")
web.type("Omega59178+",into="password")

# %%
web.click("SE CONNECTER",id="submit")

# %%
# web.go_to("https://agora.univ-catholille.fr/isacademia/PORTAL3S.htm#tab23")
web.click("Saisie des notes",id="BB122145177_1")

# %%
web.click("L2 JV")

# %%
import pandas as pd

# %%
df = pd.read_csv("Visual_notes.csv",sep=',',index_col=[0,1],header=None)
notes = df[2].map(lambda i : eval(i.replace(',','.'))).to_dict()
notes = {str.lower(a) + " " + str.lower(b):notes[(a,b)] for a,b in notes.keys()}
print(notes)
df.sort_index()
# Out:
# {'charlet samuel': 16.43, 'billemont jérôme': 15.95, 'amies leyna': 16.19, 'antonio manuel': 16.19, 'bastard gabin': 15.95, 'caille jean-charles': 15.95, 'lepers nicolas': 13.81, 'hache arthur': 14.05, 'batsleer cyane': 13.1, 'gournay  victor': 13.1, 'charlet  ludovic': 14.05, 'derisquebourg gaspard': 14.05, 'gestin louis': 11.19, 'masselot remy': 11.9, 'detollenaere tristan': 11.19, 'islam mohima': 11.19, 'vase ugo': 11.9, 'logez remi': 11.9, 'pecquet iris': 13.57, 'benaissa  matteo': 13.57, 'aubart adam': 12.86, 'henneron  mateo': 12.86, 'vandeweghe louise': 12.86, 'hodé sacha': 13.57, 'outteryck romy': 13.57, 'walenczak simon': 18.57, 'zalisz valentin': 17.14, 'liferki selma': 17.14, 'lannuzel alicia': 17.14, 'gontier  luc': 18.57, 'goulam rasoul  naël': 18.57, 'masson jean-loup': 18.57}
#                                  2
# 0              1
# Amies          Leyna         16,19
# Antonio        Manuel        16,19
# Aubart         Adam          12,86
# ...

# %%
web.press(web.Key.TAB)
notes = df.to_dict()
notes
# Out:
# {'note': {'BOUILLARD Elie': 13.0,
#   'BRUYERE Alice': 14.67,
#   'Choquet Inès': 13.33,
#   'COEUGNIET Félix': 17.2,
#   'DARRAS Julien': 11.0,
#   'DECOUTURE Nicolas': 13.0,
#   'DUBAR Romain': 15.2,
#   'DUPRAT Louis': 11.0,
#   'JAVELLE Etienne': 17.2,
#   'LEJUSTE Paul': 10.67,
#   'MAINCZYK Jade': 10.67,
#   'MOKTEFI Sonia': 14.67,
#   'QUEROIX Yanis': 13.33,
#   'ROSSAT Jeanne': 15.2,
#   'Sileghem Cyrielle': 8.0,
#   'STAQUET Sylvain': 8.0,
#   'Winants Quentin': 13.0}}

# %%
source = web.get_page_source()

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(source)
soup
# Out:
# <html lang="fr" xmlns:ewnet="images/ewnet"><head><style type="text/css">.swal-icon--error{border-color:#f27474;-webkit-animation:animateErrorIcon .5s;animation:animateErrorIcon .5s}.swal-icon--error__x-mark{position:relative;display:block;-webkit-animation:animateXMark .5s;animation:animateXMark .5s}.swal-icon--error__line{position:absolute;height:5px;width:47px;background-color:#f27474;display:block;top:37px;border-radius:2px}.swal-icon--error__line--left{-webkit-transform:rotate(45deg);transform:rotate(45deg);left:17px}.swal-icon--error__line--right{-webkit-transform:rotate(-45deg);transform:rotate(-45deg);right:16px}@-webkit-keyframes animateErrorIcon{0%{-webkit-transform:rotateX(100deg);transform:rotateX(100deg);opacity:0}to{-webkit-transform:rotateX(0deg);transform:rotateX(0deg);opacity:1}}@keyframes animateErrorIcon{0%{-webkit-transform:rotateX(100deg);transform:rotateX(100deg);opacity:0}to{-webkit-transform:rotateX(0deg);transform:rotateX(0deg);opacity:1}}@-webkit-keyframes an
# ...

# %%
htmlTable = soup.find("table",id="laTable").find("tbody")
# html_df = pd.read_html(str(htmlTable))[0]
# print(list(notes['note'].keys())[1])
for element in htmlTable.find_all("tr",style="background:"):
    print(element.get("id"))
    name = str(element.find("td")).replace("<td>","").replace("</td>","")
    print(str.lower(name))
    if (str.lower(name) in notes.keys()) :

        namenote =notes[str.lower(name)]
        print(namenote)#.get("name")
        for i in element.find_all('input',type="text"):
            elementid = i.get("id")
            print(elementid)
            web.type(str(namenote),id=elementid)
            break
        print()
# Out:
# row1
# amies leyna
# 16.19
# ww_x_note_col_1_5784040098_402652607
#
# row2
# antonio manuel
# 16.19
# ww_x_note_col_1_5783830231_402652607
#
# row3
# aubart adam
# 12.86
# ww_x_note_col_1_5783834812_402652607
#
# row4
# bastard gabin
# 15.95
# ww_x_note_col_1_5783831090_402652607
#
# row5
# batsleer cyane
# 13.1
# ww_x_note_col_1_5783831662_402652607
#
# row6
# benaissa matteo
# row7
# billemont jérôme
# 15.95
# ww_x_note_col_1_5783830517_402652607
#
# row8
# caille jean-charles
# 15.95
# ww_x_note_col_1_5783835956_402652607
#
# row9
# charlet ludovic
# row10
# charlet samuel
# 16.43
# ww_x_note_col_1_5783830804_402652607
#
# row11
# derisquebourg gaspard
# 14.05
# ww_x_note_col_1_5783835098_402652607
#
# row12
# detollenaere tristan
# 11.19
# ww_x_note_col_1_5783833096_402652607
#
# row13
# gestin louis
# 11.19
# ww_x_note_col_1_5815123213_402652607
#
# row14
# gontier luc
# row15
# goulam rasoul naël
# row16
# gournay victor
# row17
# hache arthur
# 14.05
# ...

# %%
for element in list(notes['note'].keys()):
    print(str.lower(element).split(" "))
# Out:
# ['bouillard', 'elie']
# ['bruyere', 'alice']
# ['choquet', 'inès']
# ['coeugniet', 'félix']
# ['darras', 'julien']
# ['decouture', 'nicolas']
# ['dubar', 'romain']
# ['duprat', 'louis']
# ['javelle', 'etienne']
# ['lejuste', 'paul']
# ['mainczyk', 'jade']
# ['moktefi', 'sonia']
# ['queroix', 'yanis']
# ['rossat', 'jeanne']
# ['sileghem', 'cyrielle']
# ['staquet', 'sylvain']
# ['winants', 'quentin']

# %%
web.type("20",)
# Out:
# Help on method type in module webbot.webbot:
#
# type(text, into='', clear=True, multiple=False, tag='input', id='', classname='', number=1, css_selector='', xpath='', loose_match=True) method of webbot.webbot.Browser instance
#     Types the text into an input field
#
#     :Args:
#         - text: The text to type in the input field.
#
#         - into: This can be any placeholder or name or value that is seen inside the input text box as seen in a browser.
#
#          If not specified, other params are considered or the first input field is selected.
#
#         - clear: Defaults to True. Clears the input field before typing the text.
#
#         - tag: defaults to 'input'. The html tag to consider for the input field (eg: textarea).
#
#         - id: id of the element to which the text must be sent.
#
#         - classname: Any class of the input element to consider while selecting the input element to send the keys to.
#
# ...
