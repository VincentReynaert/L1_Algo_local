# %%
from webbot import Browser

# %%
web = Browser()

# %%
web.go_to("https://agora.univ-catholille.fr/isacademia/PORTAL3S.htm")

# %%
web.type("2016546053",into="username")
web.type("Omega59178+",into="password")

# %%
web.click("SE CONNECTER",id="submit")

# %%
web.go_to("https://agora.univ-catholille.fr/isacademia/PORTAL3S.htm#tab23")

# %%
web.click("M1 JV S1")

# %%
import pandas as pd

# %%
df = pd.read_csv("note.csv",sep=';',index_col='id')

# %%
web.press(web.Key.TAB)
notes = df.to_dict()
notes
# Out:
# {'note': {'BOUILLARD Elie': 13.0,
#   'BRUYERE Alice': 14.67,
#   'Choquet Inès': 13.33,
#   'COEUGNIET Félix': 17.2,
#   'DARRAS Julien': 11.0,
#   'DECOUTURE Nicolas': 13.0,
#   'DUBAR Romain': 15.2,
#   'DUPRAT Louis': 11.0,
#   'JAVELLE Etienne': 17.2,
#   'LEJUSTE Paul': 10.67,
#   'MAINCZYK Jade': 10.67,
#   'MOKTEFI Sonia': 14.67,
#   'QUEROIX Yanis': 13.33,
#   'ROSSAT Jeanne': 15.2,
#   'Sileghem Cyrielle': 8.0,
#   'STAQUET Sylvain': 8.0,
#   'Winants Quentin': 13.0}}

# %%
source = web.get_page_source()

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(source)
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
# ...

# %%
print(soup.get(id="laTable"))
print(list(notes['note'].keys())[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\VREYNA~1\AppData\Local\Temp/ipykernel_28984/2486293735.py in <module>
# ----> 1 print(soup.get(id="laTable"))
#       2 print(list(notes['note'].keys())[1])
#
# TypeError: get() got an unexpected keyword argument 'id'

# %%
web.click(id="row1")

# %%
web.type("20",)
# Out:
# Help on method type in module webbot.webbot:
#
# type(text, into='', clear=True, multiple=False, tag='input', id='', classname='', number=1, css_selector='', xpath='', loose_match=True) method of webbot.webbot.Browser instance
#     Types the text into an input field
#
#     :Args:
#         - text: The text to type in the input field.
#
#         - into: This can be any placeholder or name or value that is seen inside the input text box as seen in a browser.
#
#          If not specified, other params are considered or the first input field is selected.
#
#         - clear: Defaults to True. Clears the input field before typing the text.
#
#         - tag: defaults to 'input'. The html tag to consider for the input field (eg: textarea).
#
#         - id: id of the element to which the text must be sent.
#
#         - classname: Any class of the input element to consider while selecting the input element to send the keys to.
#
# ...
